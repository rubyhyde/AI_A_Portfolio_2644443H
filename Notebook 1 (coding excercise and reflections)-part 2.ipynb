# %% [markdown]
# ## Simplicity, Security, Inclusion
#
# ### 1. Emphasizing Simplicity
#
# The simplest form of "Hello, World!" focuses on readability and minimalism.

# %%
# Simple Hello, World! program
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# #### Steps:
#
# 1.  **Write the statement:** The `print()` function displays the message to the console.
# 2.  **Provide the message:** Enclose `"Hello, World!"` in double quotes.
#
# #### Key Aspects:
#
# * Python’s philosophy values simplicity and readability, following the "Zen of Python" (e.g., "Simple is better than complex").
# * This is the most basic and beginner-friendly approach with no unnecessary code.
#
# ### 2. Emphasizing Security
#
# A more secure approach involves modularizing code and adding docstrings for clarity. This helps prevent issues in larger programs.

# %%
def safe_message():
    """
    Returns a safe greeting message.
    """
    return "Hello, World!"

if __name__ == "__main__":
    print(safe_message())
# Out:
# Hello, World!

# %% [markdown]
# #### Steps:
#
# 1.  **Define a function:** `safe_message()` encapsulates the greeting. Functions promote modularity and code reusability.
#
# 2.  **Add docstrings:** A docstring is included to describe the function’s purpose for clarity.
#
# 3.  **Use `if __name__ == "__main__":`:** This prevents the code from executing when the script is imported elsewhere.
#
# #### Key Aspects:
#
# * **Modularity:** Code is reusable and testable when structured in functions.
#
# * **Security:** Avoids exposing sensitive logic or hardcoding values in an insecure way.
#
# * **Context Protection:** The `if __name__ == "__main__":` construct ensures that code is executed only when the script is run directly.
#
# ### 3. Emphasizing Inclusion
#
# To promote inclusivity, the program adapts to user preferences by offering greetings in different languages.

# %%
def hello_world(language="en"):
    """
    Returns a greeting message in the specified language.
    """
    messages = {
        "en": "Hello, World!",   # English
        "es": "¡Hola, Mundo!",   # Spanish
        "fr": "Bonjour, Monde!", # French
        "ja": "こんにちは、世界！",  # Japanese
    }
    return messages.get(language, "Hello, World!")  # Default to English

# Ask for user preference
user_language = input("Enter your preferred language code (e.g., 'en', 'es', 'fr', 'ja'): ")
print(hello_world(user_language))
# Out:
# ¡Hola, Mundo!

# %% [markdown]
# #### Steps:
#
# 1.  **Define a function:** `hello_world(language)` returns a greeting in the user’s preferred language.
# 2.  **Create a dictionary:** `messages` stores greetings in various languages, supporting inclusivity.
# 3.  **Provide a default option:** Using `.get()`, we ensure that if the user inputs an unsupported language code, it defaults to English.
# 4.  **User Interaction:** The `input()` function prompts the user to specify their language preference.
#
# #### Key Aspects:
#
# * **Diverse Audience:** This approach supports multiple languages, showing respect for global audiences.
# * **Fallback:** The default value ("Hello, World!") ensures accessibility for users with unsupported language codes.
# * **User Preference:** The program engages users by adapting to their language choices.
#
# #### Reflection:
#
# This approach demonstrates how inclusivity can be incorporated into code by making it adaptable to different user preferences, promoting accessibility, and fostering a sense of respect for diverse languages and cultures.
#
# #### Learning Outcomes
#
# * **Simplicity:** I learned how Python’s simplicity can enhance readability, making it ideal for beginners.
# * **Security:** Modularizing code and using constructs like `if __name__ == "__main__":` provides better security and avoids unintended execution.
# * **Inclusion:** Offering multi-language support with a fallback option ensures that the program is accessible to diverse audiences.
#
# I really enjoyed thinking about Python from a more philosophical perspective, considering how simplicity, security, and inclusion can be embraced in the design and implementation of code.
#
# ---
# ## YouTube Fun

# %%
#import video software
from IPython.display import YouTubeVideo

# %%
#embed video into notebook
YouTubeVideo("nE178FMQ1MQ")

# %% [markdown]
# #### Peer Discussion
#
# When troubleshooting the YouTube embedding, we found that some errors stemmed from missing the IPython library. This prompted a discussion about how to correctly use the terminal to install libraries and the importance of checking for successful installation before proceeding with the code as intially mine didn't work because my library wasn't updated.
#
# ---
#
# ## Internet Archive Wayback Machine Program
# **How many libraries are imported?**
#
# Two libraries, webbrowser and requests.
#
# **How many variables are used?**
#
# Six variables used: site, era, url, response, data, and old_site.
#
# **How many strings appear in the program?**
#
# "Shall we hunt down an old website?"
# "Type a website URL: "
# "Type year, month, and date, e.g., 20150613: "
# "http://archive.org/wayback/available?url=%s&amp;timestamp=%s"1
# "Found this copy: "
# "It should appear in your browser."
# "Sorry, could not find the site."
#
# **How many times is something printed? What is printed each time?**
#
# Something is printed four times:
# "Shall we hunt down an old website?"
# The website URL the user inputs (indirectly, as part of the prompt)
# "Found this copy: ", followed by the archived website URL
# "It should appear in your browser."
# "Sorry, could not find the site

# %%
import webbrowser
import requests
print("Shall we hunt down an old website?")
site = input("Type a website URL: ")
era = input("Type year, month, and date, e.g., 20150613: ")
url = "http://archive.org/wayback/available?url=%s&timestamp=%s" % (site, era)
response = requests.get(url)
data = response.json()
try:
    old_site = data["archived_snapshots"]["closest"]["url"]
    print("Found this copy: ", old_site)
    print("It should appear in your browser.")
    webbrowser.open(old_site)
except:
    print("Sorry, could not find the site.")


import webbrowser  # Imports the webbrowser library, which is for opening web pages
import requests  # Imports the requests library, which is used for making web requests

print("Shall we hunt down an old website?")  # Prints a prompt to the user

site = input("Type a website URL: ")  # Gets the website URL from the user and stores it in the 'site' variable
era = input("Type year, month, and date, e.g., 20150613: ")  # Gets the date from the user and stores it in the 'era' variable

url = "http://archive.org/wayback/available?url=%s&timestamp=%s" % (site, era)  # Constructs the URL for the Wayback Machine API using string formatting with 'site' and 'era'
response = requests.get(url)  # Sends a GET request to the Wayback Machine and saves the response
data = response.json()  # Parses the JSON response from the Wayback Machine

try:  # Begins a try block, which I think is for error handling
    old_site = data["archived_snapshots"]["closest"]["url"]  # Extracts the archived URL from the JSON data, navigating through nested dictionaries
    print("Found this copy: ", old_site)  # Prints the archived URL
    print("It should appear in your browser.")  # Prints a message to the user
    webbrowser.open(old_site)  # Opens the archived URL in the user's web browser
except:  # Handles the exception if the 'try' block fails (e.g., if the site isn't found)
    print("Sorry, could not find the site.")  # Prints an error message
# Out:
# Shall we hunt down an old website?
# Sorry, could not find the site.
# Shall we hunt down an old website?
# Sorry, could not find the site.

# %% [markdown]
# ### Reflection
#
# While analysing the Wayback Machine code, I initially struggled with identifying all the variables. I incorrectly counted five variables, failing to include url. This mistake was a valuable learning experience. It made me revise the definition of a variable and recognise that any name assigned a value, regardless of how that value is obtained, is indeed a variable. This aided my understanding of how variable function within Python.
#
# ---

# %% [markdown]
# ## Displaying Images and Audio

# %%
#prompt for image
from IPython.display import Image

# %%
Image("picture1.jpg")

# %%
#prompt for audio
from IPython.display import Audio

# %%
#import audio 1
Audio("audio1.mid")
# Out:
#                 <audio  controls="controls" >
#                     <source src="..." type="audio/midi" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Scikit-Learn Datasets
#
# **Prompt: Can you show me how to load datasets using sklearn for a total beginner?**
#
# ### Loading Datasets
#
# #### 1. Install sklearn
#
# First, ensure you have sklearn installed. You can install it using pip:

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 1. Import the necessary libraries

# %%
#importing the libraries
import numpy as np
import pandas as pd
from sklearn import datasets

# %% [markdown]
# #### 3. Load a dataset
#
# sklearn comes with several built-in datasets. Let's start with the Iris dataset, which is commonly used for beginners:

# %%
iris = datasets.load_iris()

# %% [markdown]
# #### 4. Explore the dataset

# %%
print(iris.keys())  # To see the keys in the dataset
print(iris['DESCR'])  # To see the description of the dataset
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# ...

# %% [markdown]
# #### 5. Convert to a DataFrame
#
# For easier manipulation, you can convert the dataset to a Pandas DataFrame:

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
print(df.head())  # To see the first few rows of the DataFrame
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# #### 6. Use the dataset
#
# Now you can use this DataFrame for your machine learning tasks, such as training a model.

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# Load the Iris dataset
iris = datasets.load_iris()

# Explore the dataset
print(iris.keys())
print(iris['DESCR'])

# Convert to a DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
print(df.head())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# ...

# %% [markdown]
# ### My Code:

# %%
from sklearn import datasets

wine = datasets.load_wine()
print(wine.keys())
print(wine['DESCR'])

df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df['target'] = wine.target
print(df.head())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid
#     - Ash
#     - Alcalinity of ash
#     - Magnesium
#     - Total phenols
#     - Flavanoids
#     - Nonflavanoid phenols
#     - Proanthocyanins
#     - Color intensity
#     - Hue
#     - OD280/OD315 of diluted wines
#     - Proline
#     - class:
#         - class_0
#         - class_1
#         - class_2
#
# :Summary Statistics:
#
# ============================= ==== ===== ======= =====
#                                 Min   Max   Mean     SD
# ============================= ==== ===== ======= =====
# Alcohol:                      11.0  14.8    13.0   0.8
# Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# ### Q&A with Copliot

# %% [markdown]
# **What is shell language you used at the start?**
#
# The shell language I used at the start is called Bash (Bourne Again SHell). It's a command language interpreter for the GNU operating system. Bash is widely used in Unix-like operating systems, including Linux and macOS, for scripting and automating tasks. For example, the command at the start is a Bash command that uses pip (Python's package installer) to install the scikit-learn library.
#
# **Define a DataFrame.**
#
# A **DataFrame** is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It is a fundamental data structure in the Pandas library, which is widely used for data manipulation and analysis in Python.
#
# **Key Features of a DataFrame:**
#
# * **Rows and Columns:** Data is organized in rows and columns, similar to a table in a database or an Excel spreadsheet.
# * **Labeled Axes:** Both rows and columns have labels, which makes it easier to access and manipulate data.
# * **Heterogeneous Data:** Different columns can contain different types of data (e.g., integers, floats, strings).

# %% [markdown]
# ### Reflection
#
# I found this task quite difficult to understand at first, as I didn’t really get how the dataset was being accessed from the library. However, using the prompts to explore the datasets and tools like Bash helped me understand the process better. I only fully understood what was happening when I tried writing my own code using load_wine, whcih I found on the scikit learn website (Scikit-learn Developers, 2025). Working through the task step by step really helped things click for me.
#
# ---

# %% [markdown]
# ### Structure
#
# **Prompt: What are features and labels in sklearn datasets? Explain with an example.**
#
# In `sklearn` datasets, **features** and **labels** are fundamental concepts used in machine learning:
#
# **Features**
#
# * Features are the input variables or attributes used to make predictions. They are the independent variables in your dataset.
# * In a dataset, features are typically represented as columns.
#
# **Labels**
#
# * Labels are the output variables or targets that you want to predict. They are the dependent variables in your dataset.
# * In a dataset, labels are usually represented as a separate column.
#
# **Example: Iris Dataset**
#
# Let's use the Iris dataset to illustrate these concepts.
#
# **Loading the Iris Dataset**

# %%
from sklearn import datasets

# Load the Iris dataset
iris = datasets.load_iris()

# %% [markdown]
# **Features**
#
# The Iris dataset has four features: *sepal length*, *sepal width*, *petal length*, and *petal width*.
# These features are stored in `iris.data`.
#
# **Labels**
#
# The labels in the Iris dataset represent the species of the iris flower (e.g., setosa, versicolor, virginica).
# These labels are stored in `iris.target`.
#
# **Exploring the Dataset**

# %%
# Features
print(iris.data[:5])  # Display the first 5 rows of features

# Labels
print(iris.target[:5])  # Display the first 5 labels
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0 0 0 0 0]

# %% [markdown]
# **Converting to a DataFrame**
#
# For better visualization, let's convert the dataset to a Pandas DataFrame:

# %%
from sklearn import datasets
import pandas as pd

# Load the Iris dataset
iris = datasets.load_iris()

# Features
print(iris.data[:5])

# Labels
print(iris.target[:5])

# Create a DataFrame for features
df_features = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add the labels to the DataFrame
df_features['target'] = iris.target

print(df_features.head())
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0 0 0 0 0]
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### My Code:

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing

# Load the California Housing dataset
california = fetch_california_housing()

# Features
print(california.data[:5])  # Display the first 5 rows of features

# Labels
print(california.target[:5])  # Display the first 5 labels

# Create a DataFrame for features
df_features = pd.DataFrame(data=california.data, columns=california.feature_names)

# Add the labels to the DataFrame
df_features['MedHouseVal'] = california.target

print(df_features.head())  # Display the first few rows of the DataFrame
# Out:
# [[ 8.32520000e+00  4.10000000e+01  6.98412698e+00  1.02380952e+00
#    3.22000000e+02  2.55555556e+00  3.78800000e+01 -1.22230000e+02]
#  [ 8.30140000e+00  2.10000000e+01  6.23813708e+00  9.71880492e-01
#    2.40100000e+03  2.10984183e+00  3.78600000e+01 -1.22220000e+02]
#  [ 7.25740000e+00  5.20000000e+01  8.28813559e+00  1.07344633e+00
#    4.96000000e+02  2.80225989e+00  3.78500000e+01 -1.22240000e+02]
#  [ 5.64310000e+00  5.20000000e+01  5.81735160e+00  1.07305936e+00
#    5.58000000e+02  2.54794521e+00  3.78500000e+01 -1.22250000e+02]
#  [ 3.84620000e+00  5.20000000e+01  6.28185328e+00  1.08108108e+00
#    5.65000000e+02  2.18146718e+00  3.78500000e+01 -1.22250000e+02]]
# [4.526 3.585 3.521 3.413 3.422]
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# ...

# %% [markdown]
# ### Q&A with Copilot

# %% [markdown]
# **Can you explain the difference between features and labels in machine learning?**
#
# **Features:**
#
# * **Definition:** Features are the input variables or attributes used to make predictions. They are the independent variables in your dataset.
# * **Example:** In a dataset about houses, features might include the number of bedrooms, square footage, and location.
# * **Role:** Features provide the information that the model uses to learn patterns and make predictions.
#
# **Labels:**
#
# * **Definition:** Labels are the output variables or targets that you want to predict. They are the dependent variables in your dataset.
# * **Example:** In the same housing dataset, the label might be the price of the house.
# * **Role:** Labels are what the model aims to predict based on the features.
#
# **Why are features and labels important in machine learning?**
#
# **Features:**
#
# * **Learning Patterns:** Features are crucial because they contain the information that the model uses to learn patterns and relationships.
# * **Model Accuracy:** The quality and relevance of features directly impact the accuracy and performance of the model. Good features lead to better predictions.
#
# **Labels:**
#
# * **Training the Model:** Labels are essential for training supervised learning models. The model learns to map features to labels during training.
# * **Evaluation:** Labels are used to evaluate the model's performance. By comparing the predicted labels to the actual labels, you can measure how well the model is performing.
#
# ### Reflection
#
# Similarly, I was initially confused by the concept of features and labels, but when I worked through another example using the Boston Housing dataset, it became much clearer. I also found that using prompts to ask Copilot why certain concepts in machine learning are important helped me gain a better overall understanding of how everything fits together.
#
# ---
#
# ### Visualisation
#
# **Prompt: How can I explore a dataset from sklearn with basic statistics and plots?**
#
# #### 1. Load the Dataset

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing

# Load the California Housing dataset
california = fetch_california_housing()

# Create a DataFrame for features
df = pd.DataFrame(data=california.data, columns=california.feature_names)

# Add the labels to the DataFrame
df['MedHouseVal'] = california.target

print(df.head())  # Display the first few rows of the DataFrame
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# #### 2. Calculate Basic Statistics

# %%
# Summary statistics
print(df.describe())
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# #### 3. Plotting the Data
#
# Matplotlib and Seaborn for plotting.

# %% [markdown]
# **Explanation:**
#
# 1.  **Load the Dataset:** Load the California Housing dataset and convert it to a Pandas DataFrame.
# 2.  **Calculate Basic Statistics:** Use `df.describe()` to get summary statistics like mean, standard deviation, min, max, and quartiles.
# 3.  **Plotting the Data:**
#     * **Histogram:** Visualize the distribution of the target variable (`MedHouseVal`).
#     * **Pairplot:** Create pairwise plots of features to see relationships between them.
#     * **Correlation Heatmap:** Visualize the correlation between features and the target variable.
#
# #### Complete Code

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import seaborn as sns

# Load the California Housing dataset
california = fetch_california_housing()

# Create a DataFrame for features
df = pd.DataFrame(data=california.data, columns=california.feature_names)
df['MedHouseVal'] = california.target

# Display the first few rows of the DataFrame
print(df.head())

# Summary statistics
print(df.describe())

# Histogram of the target variable
plt.figure(figsize=(10, 6))
sns.histplot(df['MedHouseVal'], bins=30, kde=True)
plt.title('Distribution of Median House Value')
plt.xlabel('Median House Value')
plt.ylabel('Frequency')
plt.show()

# Pairplot of features
sns.pairplot(df, diag_kind='kde')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %% [markdown]
# ### Q&A with Copilot
#
# **What are the different types of data visualizations and when should I use each type?**
#
# 1.  **Histograms**
#     * **Purpose:** To show the distribution of a single variable.
#     * **Use Case:** When you want to understand the frequency of data points within different ranges.
#     * **Example:** Visualizing the distribution of house prices.
#
# 2.  **Bar Charts**
#     * **Purpose:** To compare different categories.
#     * **Use Case:** When you want to compare the values of different groups.
#     * **Example:** Comparing sales figures across different regions.
#
# 3.  **Line Plots**
#     * **Purpose:** To show trends over time.
#     * **Use Case:** When you want to visualize how a variable changes over time.
#     * **Example:** Plotting stock prices over a year.
#
# 4.  **Scatter Plots**
#     * **Purpose:** To show the relationship between two variables.
#     * **Use Case:** When you want to identify correlations or patterns between two variables.
#     * **Example:** Plotting height vs. weight.
#
# 5.  **Box Plots**
#     * **Purpose:** To show the distribution of data based on quartiles.
#     * **Use Case:** When you want to visualize the spread and identify outliers.
#     * **Example:** Comparing test scores across different classes.
#
# 6.  **Heatmaps**
#     * **Purpose:** To show data density or correlation.
#     * **Use Case:** When you want to visualize the intensity of data points or the correlation between variables.
#     * **Example:** Visualizing the correlation matrix of features in a dataset.
#
# 7.  **Pie Charts**
#     * **Purpose:** To show the proportion of categories.
#     * **Use Case:** When you want to visualize the percentage distribution of different categories.
#     * **Example:** Showing the market share of different companies.
#
# **Why is data visualization important in data analysis?**
#
# 1.  **Simplifies Complex Data**
#     * **Explanation:** Visualizations make complex data more accessible and understandable by presenting it in a graphical format.
#
# 2.  **Identifies Patterns and Trends**
#     * **Explanation:** Helps in identifying patterns, trends, and correlations that might not be apparent in raw data.
#
# 3.  **Facilitates Communication**
#     * **Explanation:** Visualizations are effective tools for communicating insights and findings to stakeholders who may not be familiar with the data.

# %% [markdown]
# 4.  **Enhances Decision Making**
#     * **Explanation:** Provides a clear and concise way to analyze data, leading to better-informed decisions.
#
# 5.  **Detects Outliers and Anomalies**
#     * **Explanation:** Helps in spotting outliers and anomalies that could indicate errors or significant findings.
#
# **What are the differences between Matplotlib, Seaborn, and Plotly?**
#
# **Matplotlib**
#
# * **Overview:** A versatile and powerful library for creating static, animated, and interactive visualizations in Python.
# * **Strengths:** Highly customizable, supports a wide range of plots, and is the foundation for many other visualization libraries.
# * **Use Case:** When you need detailed control over every aspect of your plot.
#
# **Seaborn**
#
# * **Overview:** Built on top of Matplotlib, Seaborn provides a high-level interface for drawing attractive and informative statistical graphics.
# * **Strengths:** Simplifies the creation of complex visualizations, integrates well with Pandas, and offers built-in themes and color palettes.
# * **Use Case:** When you need to create statistical plots with less code and more aesthetic appeal.
#
# **Plotly**
#
# * **Overview:** A library for creating interactive visualizations that can be easily shared and embedded in web applications.
# * **Strengths:** Supports interactive plots, integrates with web technologies, and offers a wide range of chart types.
# * **Use Case:** When you need interactive and web-based visualizations.
#
# **Summary:**
#
# * **Matplotlib:** Best for detailed control and customization.
# * **Seaborn:** Best for statistical plots and ease of use.
# * **Plotly:** Best for interactive and web-based visualizations.

# %% [markdown]
# ### My Code

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Wine dataset
wine = load_wine()

# Create a DataFrame for features
df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df['target'] = wine.target

# Display the first few rows of the DataFrame
print(df.head())

# Summary statistics
print(df.describe())

# Histogram of the target variable
plt.figure(figsize=(10, 6))
sns.histplot(df['target'], bins=3, kde=True)
plt.title('Distribution of Wine Classes')
plt.xlabel('Wine Class')
plt.ylabel('Frequency')
plt.show()

# Scatter plot of 'alcohol' vs 'malic_acid'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='alcohol', y='malic_acid', data=df, hue='target')
plt.title('Alcohol vs Malic Acid')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')
plt.show()

# Box plot of 'alcohol' grouped by 'target'
plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='alcohol', data=df)
plt.title('Alcohol Content by Wine Class')
plt.xlabel('Wine Class')
plt.ylabel('Alcohol Content')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %% [markdown]
# ### Reflection
#
# For me, being able to visualise the datasets has been invaluable. It’s led to a much deeper understanding of all the previous tasks I’ve been working on. I’m already familiar with using different types of data visualisations through Excel, so I’m aware of how important they are, but seeing Copilot’s explanation of why visualisation matters from an AI perspective gave me a new perspective on it.
#
# ---

# %% [markdown]
# ## Pandas Basic Concepts
#
# **Prompt: Explain these concepts about Panda to a beginner...**
#
# ### 1. Installation and Setup

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ### 2. Understanding Data Structures
#
# Pandas primarily uses two data structures: **Series** and **DataFrame**.
#
# **Series:** A one-dimensional array-like object that can hold any data type. It's similar to a column in a spreadsheet.
#
# **DataFrame**: A two-dimensional table with rows and columns. It's similar to a spreadsheet or SQL table.

# %%
s = pd.Series([1, 2, 3, 4])

# %%
data = {'Name': ['Tom', 'Jerry'], 'Age': [5, 6]}
df = pd.DataFrame(data)

# %% [markdown]
# ### 3.Creating Data Frames
#
# You can create DataFrames in several ways:
# * From lists
# * From CSV Files
# * From Scikit-Learn datasets

# %%
#from lists
import pandas as pd

data = [['Tom', 5], ['Jerry', 6]]
df = pd.DataFrame(data, columns=['Name', 'Age'])
print(df)
# Out:
#     Name  Age
# 0    Tom    5
# 1  Jerry    6

# %%
#from sklearn.datasets
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### 4. Reading Data
#
# You can read data from various sources:
#
# * **Reading CSV files**
#
#     df = pd.read_csv('file.csv'
#
# * **Reading Excel files**
#
#     df = pd.read_excel('file.xlsx'
#
# * **Reading SQL databases**
#
#     import sqlite3
#
#     conn = sqlite3.connect('database.db')
#
#     df = pd.read_sql_query('SELECT * FROM table_name', conn
#
#
#
# ### 5. Inspecting Data
#
# * **You can view the first few rows**
#
#     print(df.head())
#
# * **You can view the last few rows**
#
#     print(df.tail())
#
# * **You can get a summary of the DataFrame**
#
#     print(df.describe())
#
# ## My Code
#
# I chose the `load_wine` dataset because I used it in the previous task and wanted to see how it looks in a more readable, format using Pandas. This dataset contains the results of a chemical analysis of wines. It is often used for classification problems in machine learning.

# %%
import pandas as pd
from sklearn.datasets import load_wine

# Load the wine dataset
wine = load_wine()

# Create a DataFrame
df = pd.DataFrame(data=wine.data, columns=wine.feature_names)

# Add the target
df['target'] = wine.target

# Display the first few rows
print(df.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %% [markdown]
# #### Exploring the Dataset

# %%
print(df.describe())  # Basic statistics
print(df['target'].value_counts())  # Check label distribution
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df, figsize=(10, 10), diagonal='kde')
plt.show()

# %% [markdown]
# ## Q&A with Copilot
#
# **What does df.describe() do in pandas?**
#
# The `df.describe()` function in pandas provides a summary of the statistical properties of the DataFrame's numerical columns. Here's what it typically includes:
#
# * **Count:** The number of non-null entries.
# * **Mean:** The average value.
# * **Standard Deviation (std):** Measures the spread of the values.
# * **Minimum (min):** The smallest value.
# * **25th Percentile (25%):** The value below which 25% of the data falls.
# * **Median (50%):** The middle value (also known as the 50th percentile).
# * **75th Percentile (75%):** The value below which 75% of the data falls.
# * **Maximum (max):** The largest value.
#
# **Why is pandas useful for machine learning?**
#
# 1.  **Data Manipulation:**
#     * Pandas provides powerful tools for manipulating data, including filtering (selecting subsets of data based on conditions), sorting (arranging data based on specific columns), and aggregating (computing summary statistics like sums, means, etc., over groups of data).
#     * **Why it's essential for ML:** Machine learning often requires specific subsets of data for training, validation, and testing. Sorting can be useful for time-series data or analyzing trends. Aggregation helps in creating new features or understanding group-level statistics.
#
# 2.  **Data Cleaning:**
#     * Machine learning models perform best on clean data. Pandas simplifies the process of handling missing values (identifying and either filling them using techniques like mean imputation or dropping rows/columns with missing data), removing duplicate entries (ensuring data integrity), and transforming data types (converting columns to the appropriate format for analysis and modeling).
#     * **Why it's essential for ML:** Missing values and duplicates can skew model training. Incorrect data types can lead to errors or suboptimal performance. Cleaning ensures the model learns from accurate and consistent information.
#
# 3.  **Data Exploration:**
#     * Pandas allows for quick and easy exploration of data. Functions like `df.describe()` (provides summary statistics), `df.head()` (displays the first few rows), and `df.info()` (shows data types and non-null counts) help you understand the structure, distribution, and basic characteristics of your dataset.
#     * **Why it's essential for ML:** Understanding the data is a crucial first step in any machine learning project. Exploration helps in identifying potential issues, gaining insights into the relationships between variables, and guiding feature engineering.
#
# 4.  **Integration with Other Libraries:**
#     * Pandas integrates seamlessly with other fundamental machine learning libraries like scikit-learn (for algorithms), TensorFlow and Keras (for deep learning), and NumPy (for numerical computations). You can easily convert data between pandas DataFrames and the array-based formats often required by these libraries.
#     * **Why it's essential for ML:** This smooth interoperability streamlines the entire machine learning workflow, from data preparation to model training and evaluation.
#
# 5.  **Handling Large Datasets:**
#     * Pandas is optimized for performance and can handle large datasets efficiently. While extremely large datasets might necessitate distributed computing frameworks, Pandas is highly capable for the majority of machine learning tasks, providing fast and memory-efficient data manipulation.
#     * **Why it's essential for ML:** Machine learning often involves large amounts of data. Pandas' efficiency allows for quicker preprocessing and analysis, saving time and computational resources.
#
# 6.  **Flexibility:**
#     * Pandas supports a wide variety of data formats, including CSV (comma-separated values), Excel spreadsheets, SQL databases, JSON, and more. This flexibility allows you to work with data from different sources without significant preprocessing overhead.
#     * **Why it's essential for ML:** Data for machine learning can come from diverse sources. Pandas' ability to handle various formats simplifies data ingestion.
#
# 7.  **Visualization:**
#     * While not primarily a visualization library itself, Pandas works very well with dedicated visualization libraries like Matplotlib and Seaborn. You can easily create insightful plots and charts directly from Pandas DataFrames to visualize data distributions, relationships between features, and model results.
#     * **Why it's essential for ML:** Visualizations are crucial for understanding data patterns, communicating findings, and evaluating model performance. Pandas' integration with these libraries makes this process straightforward.
#
#     ### Reflections
#
#     Using Pandas really helped me make sense of the wine dataset. I found it useful to see the data laid out in a clear table rather than just printed as arrays. Initially, I didn’t understand how the `DataFrame` was created, but asking Copilot to “explain the structure of a pandas DataFrame for a beginner” helped a lot as it didn't over complicat it. I also explored `.describe()` which showed me summary statistics, which I’m familiar with from Excel, so that made it easier to interpret.

# %% [markdown]
# ---
#
# ## Reference List
#
# * Python Software Foundation, n.d. *PEP 8 – Style Guide for Python Code*. Available at: https://peps.python.org/pep-0008/ \[Accessed 05 March 2025].
# * Reitz, K., n.d. *The Hitchhiker's Guide to Python*. Available at: https://docs.python-guide.org/ \[Accessed 05 March 2025].
# * Scikit-learn. (2024). sklearn.datasets: Dataset loading utilities. Available at: https://scikit-learn.org/stable/api/sklearn.datasets.html (Accessed: 15 March 2025).
# * GitHub. (2024). GitHub Copilot. Available at: https://github.com/features/copilot (Accessed: 15 March 2025).
